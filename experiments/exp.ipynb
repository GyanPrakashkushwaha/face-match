# %%
import os
import pandas as pd
import pickle

# %%
os.getcwd()
# Out:
# 'd:\\vscode_machineLearning\\BEST_PROJECTS\\face-match\\src\\experiments'

# %%
os.chdir('d:\\vscode_machineLearning\\BEST_PROJECTS\\face-match')

# %%
os.getcwd()
# Out:
# 'd:\\vscode_machineLearning\\BEST_PROJECTS\\face-match'

# %%
os.listdir('data')

img_file_path_list = [actors for actors in os.listdir('data') for file in os.listdir(os.path.join('data',actors))]
img_file_path_list
# Out:
# ['Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
#  'Aamir_Khan',
# ...

# %%
img_file_path = []
for actors in os.listdir('data'):
    for file in os.listdir(os.path.join('data',actors)):
        img_file_path.append(os.path.join('data',actors,file))
        # print(os.path.join('data',actors,file))

img_file_path
# Out:
# ['data\\Aamir_Khan\\Aamir.100.jpg',
#  'data\\Aamir_Khan\\Aamir.101.jpg',
#  'data\\Aamir_Khan\\Aamir.103.jpg',
#  'data\\Aamir_Khan\\Aamir.105.jpg',
#  'data\\Aamir_Khan\\Aamir.106.jpg',
#  'data\\Aamir_Khan\\Aamir.111.jpg',
#  'data\\Aamir_Khan\\Aamir.112.jpg',
#  'data\\Aamir_Khan\\Aamir.113.jpg',
#  'data\\Aamir_Khan\\Aamir.115.jpg',
#  'data\\Aamir_Khan\\Aamir.116.jpg',
#  'data\\Aamir_Khan\\Aamir.118.jpg',
#  'data\\Aamir_Khan\\Aamir.120.jpg',
#  'data\\Aamir_Khan\\Aamir.121.jpg',
#  'data\\Aamir_Khan\\Aamir.123.jpg',
#  'data\\Aamir_Khan\\Aamir.125.jpg',
#  'data\\Aamir_Khan\\Aamir.128.jpg',
#  'data\\Aamir_Khan\\Aamir.129.jpg',
#  'data\\Aamir_Khan\\Aamir.130.jpg',
#  'data\\Aamir_Khan\\Aamir.132.jpg',
#  'data\\Aamir_Khan\\Aamir.134.jpg',
#  'data\\Aamir_Khan\\Aamir.142.jpg',
#  'data\\Aamir_Khan\\Aamir.144.jpg',
#  'data\\Aamir_Khan\\Aamir.151.jpg',
#  'data\\Aamir_Khan\\Aamir.153.jpg',
#  'data\\Aamir_Khan\\Aamir.158.jpg',
#  'data\\Aamir_Khan\\Aamir.161.jpg',
# ...

# %%
pickle.dump(obj=img_file_path,file=(open(file='model/img_files_path.pkl',mode='wb')))

# %%
df = pd.DataFrame(data=img_file_path,columns=['img_path'])

# %%
df.columns
# Out:
# Index(['img_path'], dtype='object')

# %%
os.makedirs('data_path/',exist_ok=True)
df.to_csv('data_path/data_path.csv')
